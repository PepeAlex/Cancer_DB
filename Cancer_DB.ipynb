# %% [markdown]
# <h1 style='text-align: center'> Cancer Deaths by US-State</h1>

# %% [markdown]
# I found this data in the site below:
#
# https://corgis-edu.github.io/corgis/csv/cancer/
#
# The data has 51 rows that correspond to US-States and 75 columns divided by numbers of Cancer Deaths subdivided by Race, Years, Sex and three kinds of cancer: Breast, Colorectal and Lung.
#
# I made some graphs to describe the data.
#
# Some libraries were imported as:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the csv file
df = pd.read_csv("cancer.csv")
# print the first 5 rows
df.head()
# Out:
#         State  Total.Rate  Total.Number  Total.Population  Rates.Age.< 18  \
# 0     Alabama       214.2       71529.0        33387205.0             2.0
# 1      Alaska       128.1        6361.0         4966180.0             1.7
# 2     Arizona       165.6       74286.0        44845598.0             2.5
# 3    Arkansas       223.9       45627.0        20382448.0             2.3
# 4  California       150.9      393980.0       261135696.0             2.6
#
#    Rates.Age.18-45  Rates.Age.45-64  Rates.Age.> 64  \
# 0             18.5            244.7          1017.8
# 1             11.8            170.9           965.2
# 2             13.6            173.6           840.2
# 3             17.6            250.1          1048.3
# 4             13.7            163.7           902.4
#
#    Rates.Age and Sex.< 18.Female  Rates.Age and Sex.< 18.Male  ...  \
# 0                            2.0                          2.1  ...
# 1                            0.0                          0.0  ...
# ...

# %%
# Graph using Matplotlib 
plt.rcParams['figure.figsize'] = (20, 7)
ax = sns.barplot(x = df["State"], y = df["Total.Population"], palette= 'dark')
ax.set_xlabel(xlabel = "State", fontsize = 10)
ax.set_ylabel(ylabel = "Total.Population" , fontsize = 10)
ax.set_title(label = "Population deaths of each US-State", fontsize = 20)
plt.xticks(rotation = 45)
plt.show()

# %%
# add some attributes and reasign with df_age
df_age = df['Rates.Age.18-45'] + df["Rates.Age.45-64"] + df["Rates.Age.> 64"]

# %%
# more graph
plt.rcParams['figure.figsize'] = (12, 20)
ax = sns.barplot(x = df_age , y = df["State"], palette= 'dark')
ax.set_xlabel(xlabel = "State", fontsize = 10)
ax.set_ylabel(ylabel = "States" , fontsize = 10)
ax.set_title(label = "Numbrers of Adult deaths(age > 18)", fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
print("Population deaths by Ages Rate")

sns.pairplot(df, x_vars=['Total.Population', 'Total.Population'], y_vars=['Rates.Age.18-45', 'Rates.Age.45-64'])

plt.show()
# Out:
# Population deaths by Ages Rate

# %% [markdown]
# # Race
#
# In this part I will work with human race and illustrate the number of deaths by kind of Cancer.
#
# ### White Race

# %%
white = df['Types.Lung.Race.White'] + df['Types.Colorectal.Race.White'] + df['Types.Lung.Race.White']

total_Breast_White = df['Types.Breast.Race.White'].sum()
total_Colorectal_White = df['Types.Colorectal.Race.White'].sum()
total_Lung_White = df['Types.Lung.Race.White'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_White, total_Colorectal_White, total_Lung_White
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in White Race\n")

plt.show()

# %% [markdown]
# ### White Non-Hispanic Race

# %%
white_non_hip = df['Types.Breast.Race.White non-Hispanic '] + df['Types.Colorectal.Race.White non-Hispanic'] + df['Types.Lung.Race.White non-Hispanic']

total_Breast_White_non_Hisp = df['Types.Breast.Race.White non-Hispanic '].sum()
total_Colorectal_White_non_Hisp = df['Types.Colorectal.Race.White non-Hispanic'].sum()
total_Lung_White_non_Hisp = df['Types.Lung.Race.White non-Hispanic'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_White_non_Hisp, total_Colorectal_White_non_Hisp, total_Lung_White_non_Hisp
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in White non-Hispanic Race\n")

plt.show()

# %% [markdown]
# ### Black Race

# %%
black = df['Types.Breast.Race.Black'] + df['Types.Colorectal.Race.Black'] + df['Types.Lung.Race.Black']

total_Breast_Black = df['Types.Breast.Race.Black'].sum()
total_Colorectal_Black = df['Types.Colorectal.Race.Black'].sum()
total_Lung_Black = df['Types.Lung.Race.Black'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_Black, total_Colorectal_Black, total_Lung_Black
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in Black Race\n")

plt.show()

# %% [markdown]
# ### Black Non-Hispanic Race

# %%
total_Breast_Black_non_Hispanic = df['Types.Breast.Race.Black non-Hispanic'].sum()
total_Colorectal_Black_non_Hispanic = df['Types.Colorectal.Race.Black non-Hispanic'].sum()
total_Lung_Black_non_Hispanic = df['Types.Lung.Race.Black non-Hispanic'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_Black_non_Hispanic, total_Colorectal_Black_non_Hispanic, total_Lung_Black_non_Hispanic
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in Black non-Hispanic Race\n")

plt.show()

# %% [markdown]
# ### Asian Race

# %%
total_Breast_Asian = df['Types.Lung.Race.Asian'].sum()
total_Colorectal_Asian = df['Types.Colorectal.Race.Asian'].sum()
total_Lung_Asian = df['Types.Lung.Race.Asian'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_Asian, total_Colorectal_Asian, total_Lung_Asian
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in Asian Race\n")

plt.show()

# %% [markdown]
# ### Indigenous Race

# %%
total_Breast_Indigenous = df['Types.Lung.Race.Indigenous'].sum()
total_Colorectal_Indigenous = df['Types.Colorectal.Race.Indigenous'].sum()
total_Lung_Indigenous = df['Types.Lung.Race.Indigenous'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_Indigenous, total_Colorectal_Indigenous, total_Lung_Indigenous
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in Indigenous Race\n")

plt.show()

# %% [markdown]
# ### Hispanic Race

# %%
total_Breast_Hispanic = df['Types.Lung.Race.Hispanic'].sum()
total_Colorectal_Hispanic = df['Types.Colorectal.Race.Hispanic'].sum()
total_Lung_Hispanic = df['Types.Lung.Race.Hispanic'].sum()

# %%
labels = ['Breast', 'Colorectal', 'Lung']
sizes = total_Breast_Hispanic, total_Colorectal_Hispanic, total_Lung_Hispanic
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Deaths by Cancer in Hispanic Race\n")

plt.show()

# %% [markdown]
# I will work in this step with the kind of Cancer by age group.
#
#
# ### Breast

# %%
# Find the sum of 
total_age18_44 = df['Types.Breast.Age.18 - 44'].sum()
total_age45_64 = df["Types.Breast.Age.45 - 64"].sum()
total_ageover64 = df["Types.Breast.Age.> 64"].sum()

# %%
labels = ['Age - 18-44', 'Age - 45-64', 'Age - >64']
sizes = total_age18_44, total_age45_64, total_ageover64
explode = (0.0, 0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Percentage of Deaths for Breast Cancer by Age\n")

plt.show()

# %%
df.plot(x="Types.Breast.Total", y=["Types.Breast.Age.18 - 44", "Types.Breast.Age.45 - 64", "Types.Breast.Age.> 64"], kind="bar", figsize=(18,14), width = 1, align='edge');
plt.title("Total Breast Cancer Deaths by Age\n\n", fontsize=20)
plt.show()

# %% [markdown]
# ### Colorectal

# %%
colorectal_gender = df['Types.Colorectal.Age and Sex.Male.18 - 44'] + df['Types.Colorectal.Age and Sex.Female.18 - 44'] + df['Types.Colorectal.Age and Sex.Male.45 - 64'] + df["Types.Colorectal.Age and Sex.Female.45 - 64"] + df["Types.Colorectal.Age and Sex.Female.> 64"] + df["Types.Colorectal.Age and Sex.Male.> 64"]

colorectal_male = df['Types.Colorectal.Age and Sex.Male.18 - 44'] + df['Types.Colorectal.Age and Sex.Male.45 - 64'] + df["Types.Colorectal.Age and Sex.Male.> 64"]

colorectal_female = df['Types.Colorectal.Age and Sex.Female.18 - 44'] + df["Types.Colorectal.Age and Sex.Female.45 - 64"] + df["Types.Colorectal.Age and Sex.Female.> 64"]

# %%
total_colorectal = colorectal_gender.sum()
total_colorectal_male = colorectal_male.sum()
total_colorectal_female = colorectal_female.sum()

# %%
labels = ['Male', 'Female']
sizes = total_colorectal_male, total_colorectal_female
explode = (0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Percentage of Deaths for Colorectal Cancer by Gender\n")

plt.show()

# %% [markdown]
# ### Lung

# %%
lung_gender = df['Types.Lung.Age and Sex.Male.18 - 44'] + df['Types.Lung.Age and Sex.Female.18 - 44'] + df['Types.Lung.Age and Sex.Male.45 - 64'] + df["Types.Lung.Age and Sex.Female.45 - 64"] + df["Types.Lung.Age and Sex.Female.> 64"] + df["Types.Lung.Age and Sex.Male.> 64"]

lung_male = df['Types.Lung.Age and Sex.Male.18 - 44'] + df['Types.Lung.Age and Sex.Male.45 - 64'] + df["Types.Lung.Age and Sex.Male.> 64"]

lung_female = df['Types.Lung.Age and Sex.Female.18 - 44'] + df["Types.Lung.Age and Sex.Female.45 - 64"] + df["Types.Lung.Age and Sex.Female.> 64"]

# %%
total_lung = lung_gender.sum()
total_lung_male = lung_male.sum()
total_lung_female = lung_female.sum()

# %%
labels = ['Male', 'Female']
sizes = total_lung_male, total_lung_female
explode = (0.0, 0.0)

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=False, startangle=45)
ax1.axis('equal')
plt.title("Percentage of Deaths for Lung Cancer by Gender\n")

plt.show()
